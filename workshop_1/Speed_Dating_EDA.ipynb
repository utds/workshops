# %% [markdown]
# # Speed Dating Data Exploratory Data Analysis

# %%
#First let's import the necessary modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import os
from IPython.display import display, HTML

pd.set_option('display.max_columns', 500)

# %%
#Specifying the Data Path

cwd = os.getcwd()
file_path = os.path.join(cwd, 'cleaned_speed_dating.csv')

# %% [markdown]
# Here, we explore some basic dataset details.

# %%
#Reading the CSV, as easy as this! df stands for dataframe
df=pd.read_csv(file_path)

# %%
df.head()
# Out:
#    iid  gender   age  date  sports  tvsports  exercise  dining  museums  art  \
# 0    1       0  21.0   7.0     9.0       2.0       8.0     9.0      1.0  1.0
# 1    1       0  21.0   7.0     9.0       2.0       8.0     9.0      1.0  1.0
# 2    1       0  21.0   7.0     9.0       2.0       8.0     9.0      1.0  1.0
# 3    1       0  21.0   7.0     9.0       2.0       8.0     9.0      1.0  1.0
# 4    1       0  21.0   7.0     9.0       2.0       8.0     9.0      1.0  1.0
#
#   ...   int_corr  samerace  attr_partner  sinc_partner  intel_partner  \
# 0 ...       0.14         0           6.0           9.0            7.0
# 1 ...       0.54         0           7.0           8.0            7.0
# 2 ...       0.61         0           7.0           6.0            8.0
# 3 ...       0.21         0           5.0           6.0            7.0
# 4 ...       0.25         0           4.0           9.0            7.0
#
#    fun_partner  amb_partner  shar_partner  prob  dec
# 0          7.0          6.0           5.0   6.0    1
# 1          8.0          5.0           6.0   5.0    1
# 2          7.0          6.0           8.0   6.0    1
# 3          7.0          6.0           6.0   6.0    1
# 4          4.0          6.0           4.0   5.0    0
#
# [5 rows x 44 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6712 entries, 0 to 6711
# Data columns (total 44 columns):
# iid              6712 non-null int64
# gender           6712 non-null int64
# age              6712 non-null float64
# date             6712 non-null float64
# sports           6712 non-null float64
# tvsports         6712 non-null float64
# exercise         6712 non-null float64
# dining           6712 non-null float64
# museums          6712 non-null float64
# art              6712 non-null float64
# hiking           6712 non-null float64
# gaming           6712 non-null float64
# clubbing         6712 non-null float64
# reading          6712 non-null float64
# tv               6712 non-null float64
# theater          6712 non-null float64
# movies           6712 non-null float64
# concerts         6712 non-null float64
# music            6712 non-null float64
# shopping         6712 non-null float64
# yoga             6712 non-null float64
# attr_want        6712 non-null float64
# sinc_want        6712 non-null float64
# intel_want       6712 non-null float64
# fun_want         6712 non-null float64
# amb_want         6712 non-null float64
# shar_want        6712 non-null float64
# attr_self        6712 non-null float64
# sinc_self        6712 non-null float64
# fun_self         6712 non-null float64
# intel_self       6712 non-null float64
# amb_self         6712 non-null float64
# pid              6712 non-null float64
# age_partner      6712 non-null float64
# int_corr         6712 non-null float64
# samerace         6712 non-null int64
# attr_partner     6712 non-null float64
# sinc_partner     6712 non-null float64
# intel_partner    6712 non-null float64
# fun_partner      6712 non-null float64
# amb_partner      6712 non-null float64
# shar_partner     6712 non-null float64
# prob             6712 non-null float64
# dec              6712 non-null int64
# dtypes: float64(40), int64(4)
# memory usage: 2.3 MB

# %%
display(df.describe())
# Out:
#                iid       gender          age         date       sports  \
# count  6712.000000  6712.000000  6712.000000  6712.000000  6712.000000
# mean    283.041716     0.509088    26.234505     4.993296     6.452771
# std     158.623235     0.499955     3.472971     1.418774     2.583173
# min       1.000000     0.000000    18.000000     1.000000     1.000000
# 25%     157.000000     0.000000    24.000000     4.000000     5.000000
# 50%     276.000000     1.000000    26.000000     5.000000     7.000000
# 75%     410.000000     1.000000    28.000000     6.000000     8.000000
# max     552.000000     1.000000    55.000000     7.000000    10.000000
#
#           tvsports     exercise       dining      museums          art  \
# count  6712.000000  6712.000000  6712.000000  6712.000000  6712.000000
# mean
# max       1.000000     10.000000     10.000000      10.000000    10.000000
#
#        amb_partner  shar_partner         prob          dec
# count  6712.000000   6712.000000  6712.000000  6712.000000
# mean      6.770113      5.472810     5.266687     0.432807
# std       1.778541      2.134391     2.131276     0.495501
# min       0.000000      0.000000     0.000000     0.000000
# 25%       6.000000      4.000000     4.000000     0.000000
# 50%       7.000000      6.000000     5.000000     0.000000
# 75%       8.000000      7.000000     7.000000     1.000000
# max      10.000000     10.000000    10.000000     1.000000

# %% [markdown]
# ### Correlation
#
# We calculate the correlation matrix of the dataframe.

# %%
corr = df.corr()
display(corr)
# Out:
#                     iid    gender       age      date    sports  tvsports  \
# iid            1.000000  0.075595  0.135121  0.025632  0.013925 -0.006568
# gender         0.075595  1.000000  0.101669 -0.110727  0.223592  0.146188
# age            0.135121  0.101669  1.000000  0.026327 -0.062181 -0.136821
# date           0.025632 -0.110727  0.026327  1.000000 -0.117405  0.007285
# sports         0.013925  0.223592 -0.062181 -0.117405  1.000000  0.487856
# tvsports      -0.006568  0.146188 -0.136821  0.007285  0.487856  1.000000
# exercise      -0.000908 -0.095595 -0.033519 -0.102151  0.398752  0.223383
# dining         0.102490 -0.223909  0.026945 -0.117231 -0.079492 -0.038711
# museums        0.051757 -0.226360  0.131839 -0.026865 -0.144879 -0.078332
# art            0.085900 -0.234823  0.091957 -0.022125 -0.141581 -0.089861
# hiking        -0.006684 -0.075168  0.060241  0.027581  0.156282 -0.007514
# gaming         0.018840  0.209828 -0.155174 -0.046236  0.138311  0.278518
# clubbing      -0.041289 -0.071205 -0.101928 -0.083578  0.064810  0.079223
# reading       -0.019751 -0.121646  0.125026  0.023614 -0.156297 -0.150767
# tv             0.000666 -0.189051 -0.183702  0.085137 -0.095122  0.264955
# theater        0.024422 -0.318675  0.008235  0.024478 -0.248350 -0.095239
# movies        -0.010122 -0.160302 -0.033948  0.050502 -0.155172 -0.033279
# concerts       0.070712 -0.126269 -0.074092  0.015090 -0.044290  0.049587
# music          0.075697 -0.073357 -0.040090  0.008106 -0.004631  0.064368
# shopping       0.080154 -0.351544 -0.164909 -0.087941 -0.108101  0.043888
# yoga           0.011717 -0.211486  0.020884 -0.050200 -0.033950 -0.070911
# attr_want      0.110353  0.352193  0.053952 -0.169578  0.190865  0.089286
# sinc_want     -0.015442 -0.118079  0.030453  0.176367 -0.054508  0.004116
# intel_want    -0.084534 -0.086996  0.066559 -0.015996 -0.167456 -0.178124
# fun_want       0.030426  0.023164 -0.093663 -0.011175  0.031486  0.023298
# amb_want      -0.149944 -0.347683 -0.116722  0.061589 -0.092792 -0.030025
# shar_want     -0.009776 -0.109481 -0.003001  0.091698 -0.054380 -0.004664
# attr_self      0.011520 -0.080572  0.032172 -0.213434  0.166208  0.075095
# sinc_self      0.071337 -0.093584 -0.020077  0.101302  0.052246  0.086306
# fun_self       0.025402 -0.137421 -0.092597 -0.142598  0.149142  0.163127
# intel_self    -0.027820  0.076725 -0.028887 -0.181756  0.141326  0.079633
# fun_want         -0.013361    -0.042747     -0.050648  0.034166  0.012261
# amb_want          0.032631     0.140811      0.031226  0.027503 -0.022152
# shar_want        -0.038813    -0.041269     -0.003628 -0.031934  0.048373
# attr_self         0.049803     0.120584      0.066057  0.267267 -0.043591
# sinc_self         0.059899     0.116691      0.036544  0.067671 -0.024623
# fun_self          0.128729     0.165505      0.111369  0.228172 -0.001594
# intel_self        0.049397     0.085068      0.048614  0.079120  0.048279
# amb_self          0.052990     0.113277      0.055618  0.064792 -0.002103
# pid              -0.003776    -0.027600     -0.048533  0.011376 -0.004303
# age_partner      -0.038596     0.019466      0.003200 -0.003938 -0.047848
# int_corr          0.011683     0.022131      0.038397  0.008866  0.011944
# samerace          0.011721     0.010970      0.057848  0.091078  0.028037
# attr_partner      0.582325     0.344256      0.481296  0.271225  0.486650
# sinc_partner      0.499545     0.451337      0.388421  0.324057  0.201887
# intel_partner     0.491548     0.618017      0.391818  0.271130  0.206550
# fun_partner       1.000000     0.487707      0.611505  0.384694  0.408790
# amb_partner       0.487707     1.000000      0.427940  0.274908  0.178523
# shar_partner      0.611505     0.427940      1.000000  0.469465  0.399857
# prob              0.384694     0.274908      0.469465  1.000000  0.310671
# dec               0.408790     0.178523      0.399857  0.310671  1.000000

# %%
corr_tmp = corr.copy()
shape = corr_tmp.values.shape

#Setting upper triangular matrix including diagonal (std) to -99, discounting them
bad_indices = np.triu_indices(shape[0])
corr_tmp.values[bad_indices] = -99

arg_corr = np.dstack(np.unravel_index(np.argsort(-corr_tmp.values.ravel()), shape))[0]

arg_corr = arg_corr[:-len(bad_indices[0])]

# %%
print('Highest Correlation Coefficient\n')

for pair in corr_tmp.columns[arg_corr]:
    print(pair, ' Correlation = ', corr[pair[0]][pair[1]])
    
print('Lowest Correlation Coefficient\n')
# Out:
# Highest Correlation Coefficient
#
# ['pid' 'iid']  Correlation =  0.993016902513
# ['art' 'museums']  Correlation =  0.853627222329
# ['intel_partner' 'sinc_partner']  Correlation =  0.660991861253
# ['music' 'concerts']  Correlation =  0.647049615544
# ['amb_partner' 'intel_partner']  Correlation =  0.61801668059
# ['shar_partner' 'fun_partner']  Correlation =  0.611504678203
# ['fun_partner' 'attr_partner']  Correlation =  0.582324761517
# ['theater' 'museums']  Correlation =  0.550602012047
# ['theater' 'art']  Correlation =  0.536958982164
# ['movies' 'theater']  Correlation =  0.504414071044
# ['fun_partner' 'sinc_partner']  Correlation =  0.499544928642
# ['fun_partner' 'intel_partner']  Correlation =  0.491548316565
# ['tvsports' 'sports']  Correlation =  0.487856104859
# ['amb_partner' 'fun_partner']  Correlation =  0.48770748
# ['dec' 'attr_partner']  Correlation =  0.486650175819
# ['shar_partner' 'attr_partner']  Correlation =  0.481296131548
# ['prob' 'shar_partner']  Correlation =  0.469465318368
# ['amb_partner' 'sinc_partner']  Correlation =  0.451336731644
# ['shopping' 'tv']  Correlation =  0.437555852114
# ['fun_self' 'attr_self']  Correlation =  0.433413492426
# ['shar_partner' 'amb_partner']  Correlation =  0.427940139477
# ['dec' 'fun_partner']  Correlation =  0.40879040942
# ['dec' 'shar_partner']  Correlation =  0.399856709621
# ['exercise' 'sports']  Correlation =  0.398752187764
# ['concerts' 'theater']  Correlation =  0.397988202021
# ['shar_partner' 'intel_partner']  Correlation =  0.391818413437
# ['concerts' 'art']  Correlation =  0.391721380314
# ['sinc_partner' 'attr_partner']  Correlation =  0.388639105894
# ['shar_partner' 'sinc_partner']  Correlation =  0.388420656475
# ['intel_self' 'attr_self']  Correlation =  0.388210643743
# ['shopping' 'dining']  Correlation =  0.385780263715
# ['prob' 'fun_partner']  Correlation =  0.384693874834
# ['concerts' 'movies']  Correlation =  0.374567369971
# ['intel_partner' 'attr_partner']  Correlation =  0.374098891624
# ['museums' 'dining']  Correlation =  0.368192995801
# ['concerts' 'museums']  Correlation =  0.365536463712
# ['movies' 'tv']  Correlation =  0.360263028007
# ['attr_want' 'gender']  Correlation =  0.352192831557
# ['amb_self' 'fun_self']  Correlation =  0.344633247581
# ['amb_partner' 'attr_partner']  Correlation =  0.344256403703
# ['amb_self' 'intel_self']  Correlation =  0.335894317858
# ['sinc_self' 'sinc_want']  Correlation =  0.330152062492
# ['amb_self' 'amb_want']  Correlation =  0.330099725247
# ['prob' 'sinc_partner']  Correlation =  0.324056731618
# ['reading' 'museums']  Correlation =  0.323688576734
# ['art' 'dining']  Correlation =  0.322272191937
# ['dec' 'prob']  Correlation =  0.310671331004
# ['yoga' 'art']  Correlation =  0.307688861113
# ['movies' 'museums']  Correlation =  0.305197407322
# ['music' 'movies']  Correlation =  0.305028435748
# ['amb_self' 'attr_self']  Correlation =  0.301984414527
# ['movies' 'art']  Correlation =  0.299220832293
# ['shopping' 'theater']  Correlation =  0.296753522338
# ['theater' 'dining']  Correlation =  0.29486498647
# ['fun_self' 'dining']  Correlation =  0.287866945043
# ['gaming' 'tvsports']  Correlation =  0.278517567459
# ['music' 'art']  Correlation =  0.277605751215
# ['prob' 'amb_partner']  Correlation =  0.27490844853
# ['prob' 'attr_partner']  Correlation =  0.27122494821
# ['prob' 'intel_partner']  Correlation =  0.27113045142
# ['intel_self' 'fun_self']  Correlation =  0.27103232173
# ['prob' 'attr_self']  Correlation =  0.267267486727
# ['tv' 'tvsports']  Correlation =  0.264954633381
# ['yoga' 'museums']  Correlation =  0.264792257027
# ['fun_self' 'shopping']  Correlation =  0.263606708348
# ['attr_self' 'exercise']  Correlation =  0.260589630257
# ['yoga' 'theater']  Correlation =  0.255160474476
# ['music' 'museums']  Correlation =  0.250925390765
# ['shopping' 'movies']  Correlation =  0.250143867741
# ['yoga' 'concerts']  Correlation =  0.245843514495
# ['fun_self' 'music']  Correlation =  0.243727342766
# ['fun_self' 'fun_want']  Correlation =  0.241814801893
# ['yoga' 'hiking']  Correlation =  0.236551003243
# ['reading' 'art']  Correlation =  0.233131219925
# ['intel_self' 'sinc_self']  Correlation =  0.228803462561
# ['prob' 'fun_self']  Correlation =  0.228171723096
# ['theater' 'tv']  Correlation =  0.226274174678
# ['sports' 'gender']  Correlation =  0.223591782854
# ['exercise' 'tvsports']  Correlation =  0.223382513855
# ['movies' 'dining']  Correlation =  0.214074077295
# ['concerts' 'dining']  Correlation =  0.213069817664
# ['music' 'theater']  Correlation =  0.212344219719
# ['amb_want' 'shopping']  Correlation =  0.211987190818
# ['gaming' 'gender']  Correlation =  0.209828178229
# ['intel_want' 'reading']  Correlation =  0.20949665712
# ['tv' 'gaming']  Correlation =  0.20906819203
# ['shopping' 'concerts']  Correlation =  0.208587304114
# ['amb_want' 'theater']  Correlation =  0.208410434029
# ['shopping' 'museums']  Correlation =  0.207841961078
# ['shopping' 'music']  Correlation =  0.206913068158
# ['dec' 'intel_partner']  Correlation =  0.206549983959
# ['fun_self' 'sinc_self']  Correlation =  0.20233156424
# ['dec' 'sinc_partner']  Correlation =  0.201887393937
# ['clubbing' 'dining']  Correlation =  0.201153715559
# ['clubbing' 'gaming']  Correlation =  0.200218719984
# ['yoga' 'shopping']  Correlation =  0.200153719763
# ['theater' 'reading']  Correlation =  0.199264900258
# ['amb_self' 'shopping']  Correlation =  0.197314710455
# ['shopping' 'art']  Correlation =  0.197149658534
# ['amb_self' 'dining']  Correlation =  0.196908250538
# ['fun_self' 'clubbing']  Correlation =  0.191078894771
# ['attr_want' 'sports']  Correlation =  0.190865264266
# ['attr_self' 'attr_want']  Correlation =  0.189368406797
# ['hiking' 'art']  Correlation =  0.188856553162
# ['attr_self' 'dining']  Correlation =  0.180841623117
# ['dec' 'amb_partner']  Correlation =  0.178523066639
# ['sinc_want' 'date']  Correlation =  0.176366974031
# ['yoga' 'dining']  Correlation =  0.175377688742
# ['hiking' 'museums']  Correlation =  0.174828074282
# ['amb_self' 'sinc_self']  Correlation =  0.172862260754
# ['intel_want' 'museums']  Correlation =  0.171496974969
# ['music' 'dining']  Correlation =  0.170493115718
# ['sinc_self' 'theater']  Correlation =  0.169845165595
# ['concerts' 'hiking']  Correlation =  0.166925977504
# ['attr_self' 'sports']  Correlation =  0.166208424964
# ['gaming' 'hiking']  Correlation =  0.165545500314
# ['amb_partner' 'fun_self']  Correlation =  0.165504730139
# ['int_corr' 'museums']  Correlation =  0.164294515164
# ['int_corr' 'art']  Correlation =  0.163990943511
# ['fun_self' 'tvsports']  Correlation =  0.163127258008
# ['amb_self' 'music']  Correlation =  0.161967494878
# ['sinc_self' 'attr_self']  Correlation =  0.161447105655
# ['attr_self' 'yoga']  Correlation =  0.159409148957
# ['yoga' 'music']  Correlation =  0.157933708203
# ['intel_partner' 'fun_self']  Correlation =  0.156925455425
# ['amb_self' 'exercise']  Correlation =  0.156572740753
# ['hiking' 'sports']  Correlation =  0.156281927877
# ['sinc_self' 'reading']  Correlation =  0.155503024215
# ['shopping' 'clubbing']  Correlation =  0.155410162929
# ['attr_self' 'shopping']  Correlation =  0.155174576726
# ['amb_self' 'sports']  Correlation =  0.152781048029
# ['int_corr' 'reading']  Correlation =  0.152038512519
# ['fun_self' 'sports']  Correlation =  0.149142309778
# ['amb_want' 'dining']  Correlation =  0.147460906873
# ['tvsports' 'gender']  Correlation =  0.146188254931
# ['intel_self' 'dining']  Correlation =  0.144485594172
# ['fun_self' 'yoga']  Correlation =  0.143970467578
# ['intel_self' 'sports']  Correlation =  0.141325749092
# ['fun_self' 'art']  Correlation =  0.141317504608
# ['amb_partner' 'amb_want']  Correlation =  0.140811078677
# ['gaming' 'sports']  Correlation =  0.13831078781
# ['sinc_self' 'concerts']  Correlation =  0.137098363867
# ['fun_self' 'concerts']  Correlation =  0.135633490161
# ['sinc_partner' 'fun_self']  Correlation =  0.135278149026
# ['intel_self' 'reading']  Correlation =  0.135207751559
# ['age' 'iid']  Correlation =  0.135121124605
# ['amb_self' 'yoga']  Correlation =  0.13244759314
# ['museums' 'age']  Correlation =  0.131838905445
# ['movies' 'reading']  Correlation =  0.13096559634
# ['fun_partner' 'fun_self']  Correlation =  0.128729445018
# ['reading' 'age']  Correlation =  0.125025898873
# ['pid' 'dining']  Correlation =  0.123580489009
# ['amb_self' 'gaming']  Correlation =  0.12325395061
# ['intel_partner' 'intel_self']  Correlation =  0.123088624628
# ['intel_partner' 'attr_self']  Correlation =  0.122447777716
# ['pid' 'age']  Correlation =  0.121430358139
# ['amb_partner' 'attr_self']  Correlation =  0.120583529958
# ['sinc_self' 'hiking']  Correlation =  0.12028523988
# ['attr_self' 'music']  Correlation =  0.119588251811
# ['attr_self' 'clubbing']  Correlation =  0.119257779954
# ['shar_want' 'amb_want']  Correlation =  0.119219688562
# ['attr_partner' 'gender']  Correlation =  0.118848492867
# ['sinc_self' 'movies']  Correlation =  0.118457061918
# ['pid' 'shopping']  Correlation =  0.118389956486
# ['intel_partner' 'tv']  Correlation =  0.118102569526
# ['prob' 'sports']  Correlation =  0.117885825553
# ['amb_partner' 'sinc_self']  Correlation =  0.116691152765
# ['intel_partner' 'sinc_self']  Correlation =  0.116671007394
# ['int_corr' 'movies']  Correlation =  0.116130876619
# ['concerts' 'gaming']  Correlation =  0.115075072777
# ['sinc_self' 'museums']  Correlation =  0.115053777169
# ['intel_partner' 'reading']  Correlation =  0.115030842945
# ['dec' 'gender']  Correlation =  0.114946341411
# ['fun_self' 'amb_want']  Correlation =  0.114323551631
# ['prob' 'exercise']  Correlation =  0.114117330701
# ['amb_partner' 'shopping']  Correlation =  0.113495410324
# ['sinc_self' 'tv']  Correlation =  0.113411384373
# ['amb_partner' 'amb_self']  Correlation =  0.11327686304
# ['yoga' 'exercise']  Correlation =  0.112736328469
# ['yoga' 'movies']  Correlation =  0.112177450102
# ['sinc_partner' 'tv']  Correlation =  0.111803130295
# ['shopping' 'gaming']  Correlation =  0.111761252745
# ['fun_self' 'exercise']  Correlation =  0.11165225225
# ['shar_partner' 'fun_self']  Correlation =  0.111368889762
# ['pid' 'art']  Correlation =  0.11100486882
# ['amb_partner' 'tv']  Correlation =  0.110822338454
# ['intel_partner' 'theater']  Correlation =  0.110725945902
# ['shopping' 'exercise']  Correlation =  0.110591512376
# ['attr_want' 'iid']  Correlation =  0.110352987929
# ['intel_want' 'art']  Correlation =  0.11035287796
# ['attr_want' 'exercise']  Correlation =  0.109930696666
# ['age_partner' 'age']  Correlation =  0.107962370287
# ['sinc_self' 'music']  Correlation =  0.10749235482
# ['amb_want' 'clubbing']  Correlation =  0.10740473656
# ['intel_self' 'exercise']  Correlation =  0.107066524724
# ['clubbing' 'art']  Correlation =  0.106885943769
# ['sinc_partner' 'sinc_self']  Correlation =  0.105488942328
# ['int_corr' 'theater']  Correlation =  0.105064822084
# ['amb_want' 'art']  Correlation =  0.104372167717
# ['amb_want' 'tv']  Correlation =  0.103276127807
# ['amb_self' 'clubbing']  Correlation =  0.102584188641
# ['dining' 'iid']  Correlation =  0.102489693771
# ['age' 'gender']  Correlation =  0.10166879569
# ['amb_partner' 'reading']  Correlation =  0.101519177067
# ['sinc_self' 'date']  Correlation =  0.101302498792
# ['age_partner' 'pid']  Correlation =  0.09995769886
# ['fun_self' 'gaming']  Correlation =  0.09945207978
# ['concerts' 'clubbing']  Correlation =  0.0990508745005
# ['sinc_want' 'movies']  Correlation =  0.0986890854029
# ['sinc_partner' 'intel_self']  Correlation =  0.0984758192578
# ['intel_want' 'theater']  Correlation =  0.0982044988983
# ['theater' 'clubbing']  Correlation =  0.0981564361304
# ['amb_want' 'yoga']  Correlation =  0.0979163374273
# ['intel_self' 'intel_want']  Correlation =  0.0974737038904
# ['attr_self' 'art']  Correlation =  0.0972289806739
# ['amb_partner' 'music']  Correlation =  0.0966755732357
# ['sinc_want' 'tv']  Correlation =  0.0964647400903
# ['dec' 'gaming']  Correlation =  0.0961668548769
# ['music' 'tv']  Correlation =  0.095518919228
# ['shar_partner' 'shopping']  Correlation =  0.0952472367354
# ['amb_want' 'museums']  Correlation =  0.0952226901548
# ['amb_partner' 'movies']  Correlation =  0.0951531912682
# ['intel_partner' 'amb_self']  Correlation =  0.0950510026706
# ['dining' 'exercise']  Correlation =  0.094727757411
# ['concerts' 'tv']  Correlation =  0.0946547584384
# ['amb_want' 'movies']  Correlation =  0.0942529473782
# ['intel_partner' 'amb_want']  Correlation =  0.0941896568129
# ['tv' 'dining']  Correlation =  0.0935808358168
# ['amb_self' 'tvsports']  Correlation =  0.0932680110831
# ['sinc_want' 'theater']  Correlation =  0.0927737362251
# ['reading' 'dining']  Correlation =  0.0922646152343
# ['amb_self' 'theater']  Correlation =  0.0921296859231
# ['sinc_partner' 'attr_self']  Correlation =  0.0920015239956
# ['art' 'age']  Correlation =  0.0919574477848
# ['shar_partner' 'gaming']  Correlation =  0.0918000797039
# ['shar_want' 'date']  Correlation =  0.0916980771235
# ['prob' 'samerace']  Correlation =  0.0910779072352
# ['fun_self' 'theater']  Correlation =  0.0908132958636
# ['sinc_self' 'dining']  Correlation =  0.0906905836786
# ['attr_self' 'museums']  Correlation =  0.0905079303089
# ['age_partner' 'iid']  Correlation =  0.0901894226138
# ['attr_want' 'tvsports']  Correlation =  0.0892855155911
# ['clubbing' 'museums']  Correlation =  0.0888162473045
# ['int_corr' 'age_partner']  Correlation =  0.0881157558904
# ['prob' 'shopping']  Correlation =  0.0880590091575
# ['amb_self' 'art']  Correlation =  0.0879882103374
# ['intel_partner' 'music']  Correlation =  0.0877930082723
# ['sinc_self' 'tvsports']  Correlation =  0.0863064637014
# ['prob' 'dining']  Correlation =  0.0861720057892
# ['fun_partner' 'music']  Correlation =  0.0860289519571
# ['intel_want' 'movies']  Correlation =  0.085938863071
# ['art' 'iid']  Correlation =  0.085899637048
# ['intel_partner' 'museums']  Correlation =  0.0857178332475
# ['amb_partner' 'theater']  Correlation =  0.0856632121346
# ['attr_self' 'amb_want']  Correlation =  0.0853777606792
# ['tv' 'date']  Correlation =  0.0851371528585
# ['amb_partner' 'intel_self']  Correlation =  0.0850684002504
# ['int_corr' 'music']  Correlation =  0.0850323249282
# ['fun_self' 'museums']  Correlation =  0.0840804037318
# ['music' 'gaming']  Correlation =  0.0838136384217
# ['sinc_self' 'yoga']  Correlation =  0.0833851155161
# ['attr_partner' 'gaming']  Correlation =  0.0832976254006
# ['sinc_self' 'art']  Correlation =  0.0829252134704
# ['gaming' 'dining']  Correlation =  0.0828037972201
# ['pid' 'concerts']  Correlation =  0.0827628741549
# ['int_corr' 'age']  Correlation =  0.0826126599438
# ['age_partner' 'amb_want']  Correlation =  0.0824346111174
# ['fun_self' 'attr_want']  Correlation =  0.0819084668657
# ['int_corr' 'intel_want']  Correlation =  0.0818643929143
# ['amb_partner' 'concerts']  Correlation =  0.0816685173187
# ['attr_want' 'gaming']  Correlation =  0.081407358526
# ['pid' 'music']  Correlation =  0.0807500502095
# ['shopping' 'iid']  Correlation =  0.0801539247141
# ['concerts' 'reading']  Correlation =  0.079900326786
# ['shar_partner' 'yoga']  Correlation =  0.0798174664145
# ['intel_self' 'tvsports']  Correlation =  0.0796329477183
# ['pid' 'sinc_self']  Correlation =  0.0795793347138
# ['clubbing' 'tvsports']  Correlation =  0.0792230692218
# ['shar_want' 'tv']  Correlation =  0.0792055871292
# ['prob' 'intel_self']  Correlation =  0.0791198604673
# ['sinc_want' 'hiking']  Correlation =  0.0775027573799
# ['intel_partner' 'shopping']  Correlation =  0.0771667772823
# ['pid' 'museums']  Correlation =  0.0771514852973
# ['movies' 'clubbing']  Correlation =  0.0771478609788
# ['hiking' 'dining']  Correlation =  0.0770189733993
# ['shar_partner' 'concerts']  Correlation =  0.0769675264558
# ['prob' 'yoga']  Correlation =  0.0768854646455
# ['intel_self' 'gender']  Correlation =  0.076724836783
# ['intel_partner' 'art']  Correlation =  0.0765414979375
# ['theater' 'hiking']  Correlation =  0.0757181222387
# ['music' 'iid']  Correlation =  0.0756965533966
# ['gender' 'iid']  Correlation =  0.0755947944068
# ['attr_self' 'tvsports']  Correlation =  0.0750948655035
# ['music' 'clubbing']  Correlation =  0.0749812705158
# ['intel_self' 'gaming']  Correlation =  0.0747475032906
# ['fun_partner' 'shopping']  Correlation =  0.0746904008236
# ['amb_self' 'tv']  Correlation =  0.0746336192217
# ['prob' 'clubbing']  Correlation =  0.0746030351589
# ['sinc_partner' 'reading']  Correlation =  0.0733283363171
# ['pid' 'attr_want']  Correlation =  0.0725760836313
# ['shar_partner' 'music']  Correlation =  0.0725154490984
# ['attr_self' 'hiking']  Correlation =  0.0723915455885
# ['fun_partner' 'tv']  Correlation =  0.0720705916531
# ['shar_want' 'concerts']  Correlation =  0.0718437008526
# ['fun_partner' 'gaming']  Correlation =  0.0716382862304
# ['sinc_self' 'iid']  Correlation =  0.0713366998726
# ['amb_partner' 'museums']  Correlation =  0.0712443996883
# ['pid' 'amb_self']  Correlation =  0.0711583757878
# ['prob' 'music']  Correlation =  0.0709803697566
# ['intel_partner' 'movies']  Correlation =  0.0708495433137
# ['concerts' 'iid']  Correlation =  0.0707123618332
# ['hiking' 'exercise']  Correlation =  0.0704607301383
# ['fun_self' 'tv']  Correlation =  0.0699150012481
# ['sinc_partner' 'music']  Correlation =  0.0697396578059
# ['sinc_partner' 'amb_self']  Correlation =  0.0697338686501
# ['amb_self' 'iid']  Correlation =  0.0684322910397
# ['attr_partner' 'intel_self']  Correlation =  0.068203465265
# ['prob' 'concerts']  Correlation =  0.0679637821015
# ['prob' 'sinc_self']  Correlation =  0.0676710616802
# ['music' 'reading']  Correlation =  0.0676499659581
# ['amb_self' 'movies']  Correlation =  0.0671938939995
# ['int_corr' 'dining']  Correlation =  0.0668578127771
# ['amb_self' 'attr_want']  Correlation =  0.0666265453873
# ['intel_want' 'age']  Correlation =  0.0665593895308
# ['shar_partner' 'attr_self']  Correlation =  0.066057121268
# ['sinc_want' 'concerts']  Correlation =  0.0658087824367
# ['sinc_partner' 'amb_want']  Correlation =  0.065072702254
# ['clubbing' 'sports']  Correlation =  0.0648101683589
# ['prob' 'amb_self']  Correlation =  0.0647923399972
# ['sinc_partner' 'art']  Correlation =  0.064746876215
# ['music' 'tvsports']  Correlation =  0.0643677687729
# ['amb_partner' 'art']  Correlation =  0.0642522557852
# ['int_corr' 'concerts']  Correlation =  0.0640237209805
# ['sinc_partner' 'tvsports']  Correlation =  0.0638854410917
# ['shar_partner' 'dining']  Correlation =  0.0636119369036
# ['sinc_partner' 'theater']  Correlation =  0.0628592234159
# ['attr_partner' 'fun_self']  Correlation =  0.0627966585318
# ['amb_want' 'hiking']  Correlation =  0.0623618545431
# ['amb_self' 'reading']  Correlation =  0.0621614405341
# ['fun_self' 'movies']  Correlation =  0.0617983741246
# ['yoga' 'clubbing']  Correlation =  0.0616567257932
# ['amb_want' 'date']  Correlation =  0.0615888117615
# ['amb_want' 'exercise']  Correlation =  0.0610679750291
# ['hiking' 'age']  Correlation =  0.0602410425301
# ['fun_partner' 'concerts']  Correlation =  0.0600801870731
# ['sinc_self' 'shar_want']  Correlation =  0.0599515375702
# ['fun_partner' 'sinc_self']  Correlation =  0.0598988948915
# ['amb_partner' 'dining']  Correlation =  0.0595446056932
# ['shar_partner' 'museums']  Correlation =  0.0592998284333
# ['sinc_partner' 'shopping']  Correlation =  0.0588304897289
# ['prob' 'gaming']  Correlation =  0.0583310745269
# ['fun_partner' 'tvsports']  Correlation =  0.0581967727072
# ['age_partner' 'art']  Correlation =  0.0578710395268
# ['shar_partner' 'samerace']  Correlation =  0.0578475469725
# ['yoga' 'reading']  Correlation =  0.0577151427104
# ['fun_partner' 'art']  Correlation =  0.0575264020698
# ['shar_partner' 'art']  Correlation =  0.0571026031355
# ['int_corr' 'pid']  Correlation =  0.0569556141223
# ['int_corr' 'iid']  Correlation =  0.0567517026177
# ['pid' 'theater']  Correlation =  0.0561507489248
# ['shar_partner' 'amb_self']  Correlation =  0.0556184989525
# ['amb_self' 'concerts']  Correlation =  0.0553035591969
# ['sinc_partner' 'movies']  Correlation =  0.0550967840111
# ['age_partner' 'museums']  Correlation =  0.0548960308401
# ['fun_partner' 'gender']  Correlation =  0.05419531223
# ['attr_want' 'age']  Correlation =  0.0539517452286
# ['intel_partner' 'exercise']  Correlation =  0.0538435793494
# ['prob' 'attr_want']  Correlation =  0.0537557567755
# ['attr_partner' 'samerace']  Correlation =  0.0532481280413
# ['fun_partner' 'amb_self']  Correlation =  0.0529903912787
# ['shar_partner' 'exercise']  Correlation =  0.0525670218722
# ['amb_partner' 'yoga']  Correlation =  0.0525264160494
# ['sinc_partner' 'museums']  Correlation =  0.0525197507076
# ['fun_partner' 'museums']  Correlation =  0.0524856561697
# ['intel_partner' 'tvsports']  Correlation =  0.0524391983238
# ['sinc_self' 'sports']  Correlation =  0.0522461991534
# ['music' 'hiking']  Correlation =  0.0519670364137
# ['museums' 'iid']  Correlation =  0.0517574486189
# ['movies' 'date']  Correlation =  0.0505019793423
# ['fun_partner' 'attr_self']  Correlation =  0.049803010284
# ['concerts' 'tvsports']  Correlation =  0.0495868551623
# ['amb_self' 'museums']  Correlation =  0.0494561212964
# ['fun_partner' 'intel_self']  Correlation =  0.0493974284771
# ['shar_partner' 'theater']  Correlation =  0.0486893196556
# ['shar_partner' 'intel_self']  Correlation =  0.048614314619
# ['dec' 'shar_want']  Correlation =  0.0483729345669
# ['dec' 'intel_self']  Correlation =  0.0482785425492
# ['intel_partner' 'concerts']  Correlation =  0.0482158289163
# ['fun_want' 'clubbing']  Correlation =  0.0480328391514
# ['fun_partner' 'sports']  Correlation =  0.0480141048163
# ['intel_self' 'shar_want']  Correlation =  0.0475395055419
# ['shar_partner' 'tvsports']  Correlation =  0.0473425885619
# ['fun_partner' 'attr_want']  Correlation =  0.0473198808259
# ['shar_partner' 'tv']  Correlation =  0.0473069116219
# ['intel_want' 'dining']  Correlation =  0.046959335789
# ['amb_self' 'hiking']  Correlation =  0.0466431907381
# ['samerace' 'intel_self']  Correlation =  0.0460608410415
# ['tv' 'exercise']  Correlation =  0.0458663891812
# ['amb_partner' 'exercise']  Correlation =  0.0454410028137
# ['samerace' 'exercise']  Correlation =  0.0450657793108
# ['reading' 'hiking']  Correlation =  0.0445773722729
# ['shopping' 'tvsports']  Correlation =  0.0438875208014
# ['intel_partner' 'dining']  Correlation =  0.0438514431101
# ['sinc_partner' 'sports']  Correlation =  0.043823705134
# ['amb_want' 'reading']  Correlation =  0.0433056931056
# ['fun_want' 'hiking']  Correlation =  0.0427547321008
# ['age_partner' 'shar_want']  Correlation =  0.0425805017767
# ['shar_partner' 'sports']  Correlation =  0.0422049893881
# ['shar_want' 'reading']  Correlation =  0.0421975958444
# ['clubbing' 'exercise']  Correlation =  0.0414343764112
# ['shar_partner' 'clubbing']  Correlation =  0.0408583576948
# ['shar_partner' 'attr_want']  Correlation =  0.0407430462272
# ['yoga' 'tv']  Correlation =  0.0405351633715
# ['intel_partner' 'int_corr']  Correlation =  0.0401719128366
# ['samerace' 'attr_self']  Correlation =  0.0398932125295
# ['sinc_self' 'gaming']  Correlation =  0.039729808665
# ['fun_partner' 'reading']  Correlation =  0.039700689427
# ['attr_partner' 'hiking']  Correlation =  0.0392093493009
# ['fun_partner' 'theater']  Correlation =  0.0390249093223
# ['pid' 'fun_self']  Correlation =  0.0388103723169
# ['shar_partner' 'int_corr']  Correlation =  0.0383971352496
# ['attr_partner' 'tv']  Correlation =  0.0381720991494
# ['amb_partner' 'clubbing']  Correlation =  0.0381608085864
# ['pid' 'date']  Correlation =  0.0380890664118
# ['attr_partner' 'sinc_self']  Correlation =  0.037991384
# ['prob' 'art']  Correlation =  0.0375462947872
# ['fun_partner' 'clubbing']  Correlation =  0.03722864767
# ['dec' 'yoga']  Correlation =  0.0371071495758
# ['sinc_want' 'reading']  Correlation =  0.0369210926221
# ['intel_partner' 'age_partner']  Correlation =  0.0367055550023
# ['shar_partner' 'sinc_self']  Correlation =  0.0365438390837
# ['intel_partner' 'sports']  Correlation =  0.0359087717055
# ['prob' 'tvsports']  Correlation =  0.0358727189241
# ['prob' 'hiking']  Correlation =  0.0357805425945
# ['amb_partner' 'tvsports']  Correlation =  0.0351659534231
# ['prob' 'museums']  Correlation =  0.0350254068041
# ['age_partner' 'hiking']  Correlation =  0.0345647813689
# ['prob' 'fun_want']  Correlation =  0.0341663464134
# ['pid' 'yoga']  Correlation =  0.0340171478591
# ['clubbing' 'hiking']  Correlation =  0.0337478394221
# ['sinc_want' 'music']  Correlation =  0.0335403829524
# ['attr_partner' 'reading']  Correlation =  0.033271699728
# ['fun_partner' 'dining']  Correlation =  0.0329157192926
# ['intel_self' 'museums']  Correlation =  0.0329117379509
# ['sinc_partner' 'gender']  Correlation =  0.0327160990301
# ['fun_partner' 'amb_want']  Correlation =  0.0326306039082
# ['int_corr' 'shar_want']  Correlation =  0.0326115783543
# ['shar_want' 'art']  Correlation =  0.0326016111815
# ['shar_want' 'yoga']  Correlation =  0.0325178355138
# ['dec' 'sinc_want']  Correlation =  0.0325122239994
# ['attr_self' 'age']  Correlation =  0.0321717735389
# ['dec' 'clubbing']  Correlation =  0.0321545960255
# ['samerace' 'intel_want']  Correlation =  0.0319771024572
# ['fun_partner' 'movies']  Correlation =  0.0318893819905
# ['sinc_self' 'exercise']  Correlation =  0.0317843980246
# ['fun_want' 'sports']  Correlation =  0.0314862525081
# ['shar_partner' 'amb_want']  Correlation =  0.0312263611297
# ['gaming' 'exercise']  Correlation =  0.0305795575999
# ['intel_partner' 'yoga']  Correlation =  0.0304751272083
# ['sinc_want' 'age']  Correlation =  0.0304530126901
# ['fun_want' 'iid']  Correlation =  0.030425744571
# ['age_partner' 'sinc_want']  Correlation =  0.0300449900207
# ['age_partner' 'theater']  Correlation =  0.0292535931981
# ['attr_self' 'reading']  Correlation =  0.029114192805
# ['amb_partner' 'gaming']  Correlation =  0.028978290524
# ['sinc_partner' 'gaming']  Correlation =  0.0284303807187
# ['samerace' 'fun_want']  Correlation =  0.0280779785543
# ['dec' 'samerace']  Correlation =  0.02803661285
# ['hiking' 'date']  Correlation =  0.0275809716838
# ['prob' 'amb_want']  Correlation =  0.027503348964
# ['dec' 'reading']  Correlation =  0.0272275621456
# ['shar_partner' 'hiking']  Correlation =  0.0270393230539
# ['dining' 'age']  Correlation =  0.0269454968147
# ['sinc_partner' 'dining']  Correlation =  0.0268401262093
# ['shar_want' 'sinc_want']  Correlation =  0.0268049391957
# ['intel_self' 'music']  Correlation =  0.0267538653911
# ['sinc_want' 'museums']  Correlation =  0.0266279610374
# ['date' 'age']  Correlation =  0.0263265300804
# ['shar_want' 'music']  Correlation =  0.0262181347285
# ['age_partner' 'exercise']  Correlation =  0.0261181409248
# ['intel_partner' 'hiking']  Correlation =  0.0257500457135
# ['pid' 'fun_want']  Correlation =  0.0257035377311
# ['date' 'iid']  Correlation =  0.0256316791667
# ['fun_self' 'iid']  Correlation =  0.0254022012338
# ['shar_partner' 'gender']  Correlation =  0.0250525249251
# ['theater' 'date']  Correlation =  0.0244778394451
# ['theater' 'iid']  Correlation =  0.0244218761489
# ['attr_partner' 'tvsports']  Correlation =  0.0236527283852
# ['reading' 'date']  Correlation =  0.0236135672759
# ['int_corr' 'yoga']  Correlation =  0.0233287636286
# ['fun_want' 'tvsports']  Correlation =  0.0232982185806
# ['age_partner' 'dining']  Correlation =  0.0232926004433
# ['fun_want' 'gender']  Correlation =  0.0231644432949
# ['movies' 'gaming']  Correlation =  0.0226518809503
# ['pid' 'tv']  Correlation =  0.0223039410975
# ['intel_partner' 'clubbing']  Correlation =  0.0222811116578
# ['amb_partner' 'int_corr']  Correlation =  0.0221309005754
# ['age_partner' 'yoga']  Correlation =  0.0217496182887
# ['shar_partner' 'movies']  Correlation =  0.0217350194952
# ['dec' 'concerts']  Correlation =  0.0215361272082
# ['dec' 'hiking']  Correlation =  0.0215333315969
# ['int_corr' 'amb_want']  Correlation =  0.0215313830203
# ['shar_partner' 'reading']  Correlation =  0.0214301834363
# ['sinc_partner' 'exercise']  Correlation =  0.0213132095554
# ['attr_want' 'clubbing']  Correlation =  0.0212730719438
# ['shar_want' 'museums']  Correlation =  0.0211674001688
# ['fun_want' 'yoga']  Correlation =  0.021124636537
# ['fun_self' 'reading']  Correlation =  0.0210917271581
# ['yoga' 'age']  Correlation =  0.0208837536528
# ['tv' 'museums']  Correlation =  0.020442345811
# ['sinc_self' 'amb_want']  Correlation =  0.0200722877038
# ['samerace' 'art']  Correlation =  0.0196423006106
# ['amb_partner' 'age_partner']  Correlation =  0.01946593751
# ['amb_want' 'music']  Correlation =  0.0193539086289
# ['pid' 'attr_self']  Correlation =  0.0193498208044
# ['sinc_partner' 'concerts']  Correlation =  0.0192838373538
# ['amb_partner' 'hiking']  Correlation =  0.0191839654608
# ['amb_partner' 'sports']  Correlation =  0.0190588389943
# ['gaming' 'iid']  Correlation =  0.018839521762
# ['int_corr' 'sinc_self']  Correlation =  0.0188012170718
# ['dec' 'art']  Correlation =  0.018438789895
# ['attr_partner' 'int_corr']  Correlation =  0.0176809556964
# ['intel_self' 'yoga']  Correlation =  0.0176144188165
# ['intel_self' 'attr_want']  Correlation =  0.017179969989
# ['samerace' 'attr_want']  Correlation =  0.0171364415356
# ['amb_partner' 'sinc_want']  Correlation =  0.0161139152847
# ['int_corr' 'sinc_want']  Correlation =  0.0159359377799
# ['concerts' 'date']  Correlation =  0.0150897989605
# ['age_partner' 'shopping']  Correlation =  0.0149702336125
# ['attr_partner' 'art']  Correlation =  0.0148033024046
# ['intel_self' 'art']  Correlation =  0.0144489444328
# ['attr_partner' 'attr_want']  Correlation =  0.014423037801
# ['samerace' 'sports']  Correlation =  0.0142157609813
# ['attr_partner' 'age']  Correlation =  0.0140449719902
# ['samerace' 'int_corr']  Correlation =  0.0140449277518
# ['sports' 'iid']  Correlation =  0.0139248907281
# ['shar_want' 'movies']  Correlation =  0.0138423076889
# ['sinc_partner' 'attr_want']  Correlation =  0.0136027986117
# ['attr_partner' 'museums']  Correlation =  0.0135990129209
# ['sinc_partner' 'fun_want']  Correlation =  0.0131375522385
# ['yoga' 'gaming']  Correlation =  0.0127939651099
# ['attr_partner' 'date']  Correlation =  0.0122763941016
# ['dec' 'fun_want']  Correlation =  0.012261238645
# ['age_partner' 'movies']  Correlation =  0.0120554050687
# ['dec' 'int_corr']  Correlation =  0.0119444234238
# ['fun_partner' 'yoga']  Correlation =  0.0118772066944
# ['fun_partner' 'samerace']  Correlation =  0.011720927094
# ['yoga' 'iid']  Correlation =  0.0117165789902
# ['fun_partner' 'int_corr']  Correlation =  0.0116831915727
# ['attr_self' 'iid']  Correlation =  0.0115202738287
# ['intel_self' 'hiking']  Correlation =  0.0115078655478
# ['prob' 'iid']  Correlation =  0.0114906445649
# ['attr_self' 'gaming']  Correlation =  0.0114405147093
# ['prob' 'pid']  Correlation =  0.01137577614
# ['pid' 'exercise']  Correlation =  0.0110820190814
# ['shar_want' 'theater']  Correlation =  0.0110201873874
# ['amb_partner' 'samerace']  Correlation =  0.0109696794626
# ['intel_partner' 'samerace']  Correlation =  0.010962006357
# ['movies' 'hiking']  Correlation =  0.010776566213
# ['fun_want' 'shopping']  Correlation =  0.0106883766986
# ['sinc_want' 'yoga']  Correlation =  0.010466950362
# ['shar_partner' 'age']  Correlation =  0.00989612461363
# ['pid' 'movies']  Correlation =  0.00965953084454
# ['attr_partner' 'fun_want']  Correlation =  0.00900658705191
# ['age_partner' 'sinc_self']  Correlation =  0.0089646444143
# ['prob' 'int_corr']  Correlation =  0.00886641634815
# ['tv' 'art']  Correlation =  0.0083694214758
# ['fun_want' 'tv']  Correlation =  0.00831358534164
# ['theater' 'age']  Correlation =  0.00823514391187
# ['music' 'date']  Correlation =  0.00810635564476
# ['age_partner' 'reading']  Correlation =  0.00776635948923
# ['amb_want' 'concerts']  Correlation =  0.00747996433337
# ['tvsports' 'date']  Correlation =  0.00728499273476
# ['fun_self' 'hiking']  Correlation =  0.00715672984146
# ['fun_partner' 'exercise']  Correlation =  0.00708889979076
# ['attr_self' 'fun_want']  Correlation =  0.00680687281836
# ['dec' 'iid']  Correlation =  0.00665214029443
# ['prob' 'theater']  Correlation =  0.00633732948981
# ['intel_partner' 'sinc_want']  Correlation =  0.0057210181416
# ['attr_partner' 'theater']  Correlation =  0.00544430093351
# ['age_partner' 'date']  Correlation =  0.00522340091951
# ['prob' 'gender']  Correlation =  0.00520667188818
# ['dec' 'theater']  Correlation =  0.00518703214119
# ['sinc_partner' 'int_corr']  Correlation =  0.00493474989991
# ['fun_partner' 'hiking']  Correlation =  0.00446378861056
# ['int_corr' 'intel_self']  Correlation =  0.00415662079648
# ['sinc_want' 'tvsports']  Correlation =  0.00411613509688
# ['attr_partner' 'yoga']  Correlation =  0.00386153567649
# ['shar_want' 'gaming']  Correlation =  0.00382914023294
# ['attr_partner' 'sports']  Correlation =  0.00339179531404
# ['shar_partner' 'age_partner']  Correlation =  0.00319966112474
# ['age_partner' 'music']  Correlation =  0.00311029530434
# ['shar_partner' 'sinc_want']  Correlation =  0.00295448949205
# ['sinc_partner' 'age_partner']  Correlation =  0.00199151836839
# ['age_partner' 'fun_self']  Correlation =  0.00197862635337
# ['attr_self' 'theater']  Correlation =  0.0016145383431
# ['dec' 'museums']  Correlation =  0.00143997368929
# ['samerace' 'hiking']  Correlation =  0.00143603719477
# ['pid' 'shar_want']  Correlation =  0.00140977540378
# ['age_partner' 'intel_self']  Correlation =  0.00100058686962
# ['theater' 'exercise']  Correlation =  0.000804382242752
# ['samerace' 'museums']  Correlation =  0.000756800291453
# ['tv' 'iid']  Correlation =  0.000665993625925
# ['samerace' 'gender']  Correlation =  0.000514044013399
# ['intel_partner' 'attr_want']  Correlation =  0.000251450860545
# ['fun_partner' 'sinc_want']  Correlation =  0.00017352100458
# ['age_partner' 'attr_self']  Correlation =  -0.000132199459085
# ['attr_partner' 'music']  Correlation =  -0.000195027958485
# ['age_partner' 'sports']  Correlation =  -0.000205012629115
# ['int_corr' 'gender']  Correlation =  -0.000268860496192
# ['pid' 'hiking']  Correlation =  -0.000270127047129
# ['dec' 'age']  Correlation =  -0.000280384800647
# ['sinc_self' 'shopping']  Correlation =  -0.000414052396982
# ['dec' 'tvsports']  Correlation =  -0.000552082242774
# ['sinc_partner' 'samerace']  Correlation =  -0.000570390357477
# ['dec' 'music']  Correlation =  -0.00087487431801
# ['exercise' 'iid']  Correlation =  -0.000908266157656
# ['fun_partner' 'iid']  Correlation =  -0.000992469298017
# ['pid' 'sinc_want']  Correlation =  -0.00148387516899
# ['dec' 'fun_self']  Correlation =  -0.00159432593826
# ['dec' 'intel_want']  Correlation =  -0.00173294415393
# ['intel_partner' 'fun_want']  Correlation =  -0.00190172802151
# ['dec' 'amb_self']  Correlation =  -0.00210349558489
# ['attr_partner' 'sinc_want']  Correlation =  -0.00214863793373
# ['music' 'exercise']  Correlation =  -0.00223456896764
# ['attr_want' 'music']  Correlation =  -0.0023780660072
# ['attr_partner' 'movies']  Correlation =  -0.00238102361483
# ['samerace' 'reading']  Correlation =  -0.00264545026173
# ['shar_want' 'hiking']  Correlation =  -0.00294579058893
# ['shar_want' 'age']  Correlation =  -0.00300135357027
# ['prob' 'reading']  Correlation =  -0.00302985119989
# ['pid' 'gaming']  Correlation =  -0.00335806505103
# ['shar_partner' 'shar_want']  Correlation =  -0.00362795541188
# ['fun_want' 'music']  Correlation =  -0.0037635917195
# ['fun_partner' 'pid']  Correlation =  -0.00377613614141
# ['prob' 'age_partner']  Correlation =  -0.00393763494445
# ['attr_partner' 'concerts']  Correlation =  -0.00410207972215
# ['dec' 'pid']  Correlation =  -0.00430286565703
# ['age_partner' 'amb_self']  Correlation =  -0.00445546344814
# ['samerace' 'age']  Correlation =  -0.00450151188077
# ['music' 'sports']  Correlation =  -0.00463096675097
# ['shar_want' 'tvsports']  Correlation =  -0.00466383643045
# ['samerace' 'age_partner']  Correlation =  -0.00467362911114
# ['intel_partner' 'gaming']  Correlation =  -0.0051981240701
# ['amb_want' 'gaming']  Correlation =  -0.00526620277295
# ['intel_self' 'movies']  Correlation =  -0.00548350011447
# ['attr_self' 'tv']  Correlation =  -0.00565761615558
# ['attr_self' 'concerts']  Correlation =  -0.00584390244325
# ['sinc_partner' 'sinc_want']  Correlation =  -0.0062215590823
# ['prob' 'age']  Correlation =  -0.00641714751612
# ['tvsports' 'iid']  Correlation =  -0.00656839418162
# ['hiking' 'iid']  Correlation =  -0.0066842032124
# ['tv' 'reading']  Correlation =  -0.00682430185535
# ['hiking' 'tvsports']  Correlation =  -0.00751442699899
# ['int_corr' 'attr_self']  Correlation =  -0.00759187022997
# ['attr_want' 'shopping']  Correlation =  -0.00787878299527
# ['pid' 'reading']  Correlation =  -0.00808454618668
# ['sinc_partner' 'date']  Correlation =  -0.00824786663559
# ['reading' 'exercise']  Correlation =  -0.00918611940763
# ['shar_want' 'iid']  Correlation =  -0.00977559128737
# ['attr_partner' 'attr_self']  Correlation =  -0.00995851907178
# ['samerace' 'amb_want']  Correlation =  -0.0101118021571
# ['movies' 'iid']  Correlation =  -0.0101218774928
# ['pid' 'sports']  Correlation =  -0.0103684541632
# ['attr_partner' 'shar_want']  Correlation =  -0.0104523400489
# ['intel_partner' 'date']  Correlation =  -0.0105490228445
# ['age_partner' 'intel_want']  Correlation =  -0.0106240560684
# ['dec' 'tv']  Correlation =  -0.0108450997238
# ['attr_partner' 'intel_want']  Correlation =  -0.010880547526
# ['tv' 'clubbing']  Correlation =  -0.0109095974442
# ['fun_want' 'date']  Correlation =  -0.0111748513368
# ['amb_partner' 'attr_want']  Correlation =  -0.0116171364369
# ['sinc_partner' 'age']  Correlation =  -0.0119093830641
# ['attr_partner' 'shopping']  Correlation =  -0.011939095091
# ['attr_partner' 'amb_want']  Correlation =  -0.0122108826029
# ['age_partner' 'concerts']  Correlation =  -0.0122195419959
# ['age_partner' 'tv']  Correlation =  -0.0126499935479
# ['attr_partner' 'amb_self']  Correlation =  -0.0127716328284
# ['amb_partner' 'date']  Correlation =  -0.0132480514828
# ['fun_partner' 'fun_want']  Correlation =  -0.0133613229636
# ['fun_partner' 'date']  Correlation =  -0.0140053704601
# ['museums' 'exercise']  Correlation =  -0.0142182849922
# ['samerace' 'amb_self']  Correlation =  -0.0146029825142
# ['int_corr' 'hiking']  Correlation =  -0.0146389458046
# ['samerace' 'theater']  Correlation =  -0.0147600401044
# ['intel_self' 'amb_want']  Correlation =  -0.0152688169745
# ['sinc_want' 'iid']  Correlation =  -0.0154421397739
# ['intel_want' 'date']  Correlation =  -0.0159963950394
# ['fun_want' 'exercise']  Correlation =  -0.016099456748
# ['intel_partner' 'age']  Correlation =  -0.0162498865898
# ['int_corr' 'date']  Correlation =  -0.0166644620819
# ['fun_partner' 'age']  Correlation =  -0.0167718815886
# ['sinc_want' 'art']  Correlation =  -0.0168877023404
# ['intel_self' 'tv']  Correlation =  -0.0170808288976
# ['sinc_want' 'gaming']  Correlation =  -0.0172227703194
# ['intel_want' 'concerts']  Correlation =  -0.0172567819563
# ['sinc_partner' 'yoga']  Correlation =  -0.0184431746042
# ['int_corr' 'exercise']  Correlation =  -0.0188706285289
# ['sinc_partner' 'hiking']  Correlation =  -0.0190509677724
# ['attr_partner' 'clubbing']  Correlation =  -0.0196266536096
# ['reading' 'iid']  Correlation =  -0.0197511757244
# ['int_corr' 'amb_self']  Correlation =  -0.0199546415399
# ['attr_partner' 'iid']  Correlation =  -0.0200075397681
# ['sinc_self' 'age']  Correlation =  -0.0200769300057
# ['art' 'exercise']  Correlation =  -0.0204901700605
# ['amb_want' 'sinc_want']  Correlation =  -0.020614519268
# ['samerace' 'shar_want']  Correlation =  -0.0210769294824
# ['intel_self' 'clubbing']  Correlation =  -0.0212828899992
# ['art' 'date']  Correlation =  -0.0221247698957
# ['dec' 'amb_want']  Correlation =  -0.0221524026832
# ['int_corr' 'fun_self']  Correlation =  -0.0224396817925
# ['samerace' 'tv']  Correlation =  -0.0228903720776
# ['fun_want' 'movies']  Correlation =  -0.0231650579219
# ['samerace' 'fun_self']  Correlation =  -0.0233215379343
# ['samerace' 'movies']  Correlation =  -0.0236765459296
# ['pid' 'tvsports']  Correlation =  -0.0238557414697
# ['dec' 'date']  Correlation =  -0.0240625257094
# ['dec' 'sinc_self']  Correlation =  -0.0246233381913
# ['sinc_partner' 'clubbing']  Correlation =  -0.0250408575395
# ['dec' 'dining']  Correlation =  -0.0250731850866
# ['attr_want' 'dining']  Correlation =  -0.0254022026803
# ['intel_self' 'shopping']  Correlation =  -0.0266896984895
# ['museums' 'date']  Correlation =  -0.026865364096
# ['samerace' 'sinc_self']  Correlation =  -0.0270704594857
# ['age_partner' 'tvsports']  Correlation =  -0.0271412573544
# ['amb_partner' 'pid']  Correlation =  -0.0276000162697
# ['intel_self' 'iid']  Correlation =  -0.0278198334806
# ['int_corr' 'fun_want']  Correlation =  -0.0279919573494
# ['dec' 'movies']  Correlation =  -0.0279976816635
# ['sinc_partner' 'iid']  Correlation =  -0.0282009928502
# ['age_partner' 'clubbing']  Correlation =  -0.028227341134
# ['attr_partner' 'pid']  Correlation =  -0.0285177862932
# ['intel_self' 'age']  Correlation =  -0.0288868964643
# ['intel_want' 'yoga']  Correlation =  -0.0289151334535
# ['amb_self' 'gender']  Correlation =  -0.0293443489833
# ['attr_partner' 'dining']  Correlation =  -0.0299742801467
# ['amb_want' 'tvsports']  Correlation =  -0.0300250743175
# ['pid' 'gender']  Correlation =  -0.0302814326334
# ['attr_want' 'concerts']  Correlation =  -0.030315291419
# ['shopping' 'reading']  Correlation =  -0.0305343127402
# ['age_partner' 'fun_want']  Correlation =  -0.0307565637718
# ['sinc_partner' 'pid']  Correlation =  -0.0311388786004
# ['prob' 'shar_want']  Correlation =  -0.0319342557871
# ['samerace' 'concerts']  Correlation =  -0.0320289551188
# ['movies' 'exercise']  Correlation =  -0.0322005891839
# ['sinc_want' 'shopping']  Correlation =  -0.0322366403945
# ['attr_self' 'movies']  Correlation =  -0.0323909112275
# ['samerace' 'iid']  Correlation =  -0.0327812736255
# ['samerace' 'pid']  Correlation =  -0.0330492207658
# ['movies' 'tvsports']  Correlation =  -0.0332789980452
# ['exercise' 'age']  Correlation =  -0.0335185370848
# ['pid' 'intel_self']  Correlation =  -0.0339457650819
# ['movies' 'age']  Correlation =  -0.0339481597591
# ['yoga' 'sports']  Correlation =  -0.0339498161378
# ['sinc_self' 'clubbing']  Correlation =  -0.0340273041617
# ['pid' 'clubbing']  Correlation =  -0.0340857631648
# ['fun_want' 'gaming']  Correlation =  -0.0341430422298
# ['intel_partner' 'pid']  Correlation =  -0.0343101920876
# ['reading' 'gaming']  Correlation =  -0.0351237310947
# ['samerace' 'tvsports']  Correlation =  -0.0355973889671
# ['dec' 'sports']  Correlation =  -0.0357748062535
# ['sinc_want' 'clubbing']  Correlation =  -0.0361610425872
# ['dec' 'attr_want']  Correlation =  -0.0363016526446
# ['shar_want' 'dining']  Correlation =  -0.0369994657325
# ['dec' 'shopping']  Correlation =  -0.0372073088436
# ['samerace' 'date']  Correlation =  -0.03740221704
# ['amb_want' 'fun_want']  Correlation =  -0.0378816954299
# ['fun_partner' 'age_partner']  Correlation =  -0.038596335619
# ['dining' 'tvsports']  Correlation =  -0.0387105258752
# ['fun_want' 'dining']  Correlation =  -0.0387802572028
# ['fun_partner' 'shar_want']  Correlation =  -0.0388129693987
# ['intel_self' 'fun_want']  Correlation =  -0.038920098649
# ['amb_self' 'fun_want']  Correlation =  -0.0392255683251
# ['amb_partner' 'age']  Correlation =  -0.0392413686898
# ['prob' 'movies']  Correlation =  -0.0396320436172
# ['music' 'age']  Correlation =  -0.0400903886997
# ['amb_partner' 'iid']  Correlation =  -0.0402965224104
# ['sinc_partner' 'shar_want']  Correlation =  -0.040406867941
# ['samerace' 'music']  Correlation =  -0.0410363939153
# ['amb_partner' 'shar_want']  Correlation =  -0.0412690385497
# ['clubbing' 'iid']  Correlation =  -0.0412891337058
# ['prob' 'sinc_want']  Correlation =  -0.0414515393015
# ['prob' 'tv']  Correlation =  -0.0414949851769
# ['intel_partner' 'iid']  Correlation =  -0.0418897057446
# ['intel_want' 'exercise']  Correlation =  -0.0423185700977
# ['intel_partner' 'intel_want']  Correlation =  -0.0426696190475
# ['amb_partner' 'fun_want']  Correlation =  -0.0427465831644
# ['fun_want' 'art']  Correlation =  -0.0429131330133
# ['intel_self' 'concerts']  Correlation =  -0.0434030641111
# ['dec' 'attr_self']  Correlation =  -0.0435908720913
# ['amb_partner' 'intel_want']  Correlation =  -0.0440870256388
# ['concerts' 'sports']  Correlation =  -0.0442901646659
# ['sinc_self' 'intel_want']  Correlation =  -0.0456611970303
# ['gaming' 'date']  Correlation =  -0.0462355574763
# ['attr_partner' 'exercise']  Correlation =  -0.0469510299362
# ['shar_partner' 'iid']  Correlation =  -0.0473989975704
# ['dec' 'age_partner']  Correlation =  -0.0478479110499
# ['attr_partner' 'age_partner']  Correlation =  -0.0480613904955
# ['sinc_partner' 'intel_want']  Correlation =  -0.0480956701384
# ['samerace' 'sinc_want']  Correlation =  -0.0484695834842
# ['shar_partner' 'pid']  Correlation =  -0.0485333207725
# ['samerace' 'gaming']  Correlation =  -0.0488890488193
# ['samerace' 'yoga']  Correlation =  -0.0496792079969
# ['yoga' 'date']  Correlation =  -0.0502004529428
# ['theater' 'gaming']  Correlation =  -0.0502283228796
# ['shar_partner' 'date']  Correlation =  -0.0503742303589
# ['shar_partner' 'fun_want']  Correlation =  -0.0506476136207
# ['intel_partner' 'shar_want']  Correlation =  -0.0518585100942
# ['attr_want' 'hiking']  Correlation =  -0.0522340957247
# ['shar_partner' 'intel_want']  Correlation =  -0.0535954586909
# ['shar_want' 'sports']  Correlation =  -0.0543800096256
# ['sinc_want' 'sports']  Correlation =  -0.0545080870068
# ['amb_want' 'intel_want']  Correlation =  -0.0583943312495
# ['gaming' 'art']  Correlation =  -0.0585649736535
# ['age_partner' 'gaming']  Correlation =  -0.0611038616937
# ['concerts' 'exercise']  Correlation =  -0.0613675866015
# ['fun_partner' 'intel_want']  Correlation =  -0.0617071112782
# ['sports' 'age']  Correlation =  -0.0621805932792
# ['samerace' 'dining']  Correlation =  -0.0623026747874
# ['int_corr' 'clubbing']  Correlation =  -0.0624706087534
# ['int_corr' 'shopping']  Correlation =  -0.0641791374207
# ['intel_partner' 'gender']  Correlation =  -0.0650904203378
# ['amb_self' 'shar_want']  Correlation =  -0.0653882677006
# ['age_partner' 'attr_want']  Correlation =  -0.065901579145
# ['samerace' 'clubbing']  Correlation =  -0.0663030411171
# ['shar_want' 'clubbing']  Correlation =  -0.0669202964377
# ['prob' 'intel_want']  Correlation =  -0.0669841623625
# ['samerace' 'shopping']  Correlation =  -0.0673234287271
# ['intel_want' 'hiking']  Correlation =  -0.0673430357618
# ['fun_want' 'reading']  Correlation =  -0.0675767110125
# ['int_corr' 'attr_want']  Correlation =  -0.0682875674532
# ['attr_want' 'yoga']  Correlation =  -0.069285138124
# ['fun_want' 'theater']  Correlation =  -0.0693428116862
# ['fun_want' 'museums']  Correlation =  -0.069410552727
# ['yoga' 'tvsports']  Correlation =  -0.0709109008076
# ['clubbing' 'gender']  Correlation =  -0.0712046125748
# ['intel_want' 'shopping']  Correlation =  -0.0713163032296
# ['attr_self' 'intel_want']  Correlation =  -0.0714835205412
# ['gaming' 'museums']  Correlation =  -0.0731203951213
# ['music' 'gender']  Correlation =  -0.0733570383093
# ['age_partner' 'gender']  Correlation =  -0.0733635744193
# ['int_corr' 'sports']  Correlation =  -0.0735379933743
# ['concerts' 'age']  Correlation =  -0.0740919749008
# ['hiking' 'gender']  Correlation =  -0.0751683979801
# ['pid' 'intel_want']  Correlation =  -0.0758624571737
# ['amb_self' 'age']  Correlation =  -0.0760517258023
# ['shar_want' 'exercise']  Correlation =  -0.0766435783244
# ['dec' 'exercise']  Correlation =  -0.0775094854648
# ['sinc_self' 'fun_want']  Correlation =  -0.078041634283
# ['museums' 'tvsports']  Correlation =  -0.0783321640368
# ['dining' 'sports']  Correlation =  -0.0794918368866
# ['fun_want' 'concerts']  Correlation =  -0.0800724469146
# ['reading' 'clubbing']  Correlation =  -0.0804876999739
# ['attr_self' 'gender']  Correlation =  -0.0805721254777
# ['sinc_want' 'dining']  Correlation =  -0.0810705838805
# ['clubbing' 'date']  Correlation =  -0.0835782286461
# ['intel_want' 'iid']  Correlation =  -0.0845335484358
# ['intel_want' 'clubbing']  Correlation =  -0.0848724427002
# ['intel_want' 'tv']  Correlation =  -0.0869944397584
# ['intel_want' 'gender']  Correlation =  -0.0869955087835
# ['intel_want' 'gaming']  Correlation =  -0.0877902252642
# ['shopping' 'date']  Correlation =  -0.0879414134114
# ['shar_want' 'shopping']  Correlation =  -0.0884464102746
# ['art' 'tvsports']  Correlation =  -0.0898613780877
# ['intel_self' 'theater']  Correlation =  -0.091943048894
# ['fun_self' 'age']  Correlation =  -0.0925968729846
# ['amb_want' 'sports']  Correlation =  -0.0927920683109
# ['amb_self' 'intel_want']  Correlation =  -0.0933392754188
# ['sinc_self' 'gender']  Correlation =  -0.0935844828248
# ['fun_want' 'age']  Correlation =  -0.0936625109284
# ['intel_want' 'music']  Correlation =  -0.0941728141221
# ['shopping' 'hiking']  Correlation =  -0.0941946723412
# ['tv' 'sports']  Correlation =  -0.0951221073488
# ['theater' 'tvsports']  Correlation =  -0.0952389089905
# ['exercise' 'gender']  Correlation =  -0.0955946495866
# ['fun_self' 'shar_want']  Correlation =  -0.101141286518
# ['clubbing' 'age']  Correlation =  -0.101927826883
# ['exercise' 'date']  Correlation =  -0.102151241519
# ['intel_want' 'sinc_want']  Correlation =  -0.102749220666
# ['attr_want' 'art']  Correlation =  -0.106750693063
# ['tv' 'hiking']  Correlation =  -0.107171582022
# ['amb_partner' 'gender']  Correlation =  -0.107330165407
# ['shopping' 'sports']  Correlation =  -0.108101404029
# ['shar_want' 'gender']  Correlation =  -0.109481059632
# ['pid' 'amb_want']  Correlation =  -0.109855697179
# ['date' 'gender']  Correlation =  -0.11072728471
# ['attr_want' 'tv']  Correlation =  -0.114601080042
# ['intel_self' 'sinc_want']  Correlation =  -0.116643830838
# ['amb_want' 'age']  Correlation =  -0.116721698601
# ['dining' 'date']  Correlation =  -0.117230684406
# ['sports' 'date']  Correlation =  -0.117405124921
# ['sinc_want' 'gender']  Correlation =  -0.118079149813
# ['sinc_want' 'exercise']  Correlation =  -0.1182618571
# ['reading' 'gender']  Correlation =  -0.121646424384
# ['prob' 'date']  Correlation =  -0.122211317024
# ['shar_want' 'intel_want']  Correlation =  -0.125666250503
# ['concerts' 'gender']  Correlation =  -0.126269328659
# ['tvsports' 'age']  Correlation =  -0.136820649286
# ['fun_self' 'gender']  Correlation =  -0.137420808873
# ['art' 'sports']  Correlation =  -0.141581177719
# ['attr_want' 'museums']  Correlation =  -0.141810704091
# ['fun_self' 'date']  Correlation =  -0.142597861088
# ['museums' 'sports']  Correlation =  -0.144879468576
# ['attr_want' 'reading']  Correlation =  -0.147426367665
# ['attr_self' 'shar_want']  Correlation =  -0.148681072809
# ['amb_want' 'iid']  Correlation =  -0.149943524007
# ['reading' 'tvsports']  Correlation =  -0.150766998673
# ['fun_self' 'sinc_want']  Correlation =  -0.153953107546
# ['movies' 'sports']  Correlation =  -0.155171732161
# ['gaming' 'age']  Correlation =  -0.155173880843
# ['reading' 'sports']  Correlation =  -0.15629657847
# ['fun_want' 'intel_want']  Correlation =  -0.15695509251
# ['movies' 'gender']  Correlation =  -0.160302291135
# ['int_corr' 'tv']  Correlation =  -0.161324372057
# ['shopping' 'age']  Correlation =  -0.16490865257
# ['attr_want' 'movies']  Correlation =  -0.166935524246
# ['intel_want' 'sports']  Correlation =  -0.167456324454
# ['sinc_self' 'attr_want']  Correlation =  -0.167859722304
# ['attr_want' 'date']  Correlation =  -0.169577912822
# ['amb_self' 'date']  Correlation =  -0.171511687942
# ['intel_want' 'tvsports']  Correlation =  -0.178123745153
# ['fun_want' 'attr_want']  Correlation =  -0.178957512455
# ['intel_self' 'date']  Correlation =  -0.181755880987
# ['tv' 'age']  Correlation =  -0.183702112373
# ['tv' 'gender']  Correlation =  -0.189051185441
# ['fun_want' 'sinc_want']  Correlation =  -0.193245408346
# ['attr_want' 'theater']  Correlation =  -0.198873710948
# ['attr_self' 'sinc_want']  Correlation =  -0.19891736384
# ['shar_want' 'fun_want']  Correlation =  -0.207647461714
# ['amb_self' 'sinc_want']  Correlation =  -0.210809798879
# ['yoga' 'gender']  Correlation =  -0.211485609904
# ['attr_self' 'date']  Correlation =  -0.213434081454
# ['fun_self' 'intel_want']  Correlation =  -0.216406257871
# ['dining' 'gender']  Correlation =  -0.223908965979
# ['museums' 'gender']  Correlation =  -0.226359946738
# ['art' 'gender']  Correlation =  -0.234823328224
# ['int_corr' 'gaming']  Correlation =  -0.237221916702
# ['int_corr' 'tvsports']  Correlation =  -0.24052740546
# ['theater' 'sports']  Correlation =  -0.248349535008
# ['theater' 'gender']  Correlation =  -0.318675122638
# ['intel_want' 'attr_want']  Correlation =  -0.327378848643
# ['amb_want' 'gender']  Correlation =  -0.347683065077
# ['shopping' 'gender']  Correlation =  -0.351544243898
# ['shar_want' 'attr_want']  Correlation =  -0.4133785283
# ['sinc_want' 'attr_want']  Correlation =  -0.433071698004
# ['amb_want' 'attr_want']  Correlation =  -0.475791530662
# Lowest Correlation Coefficient

# %% [markdown]
# Look at the correlations above. Are there any results that you weren't expecting?

# %% [markdown]
# ### Data Visualization

# %%
from mpl_toolkits.mplot3d import Axes3D

def plotTwoFeatures(f1, f2):
    fig = plt.figure()
    plt.plot(df[f1], df[f2], 'o')
    plt.xlabel(f1)
    plt.ylabel(f2)

# %%
#Hard to see for first two, these are only integers

plotTwoFeatures('art', 'museums')
plotTwoFeatures('intel_partner', 'sinc_partner')
plotTwoFeatures('amb_want', 'attr_want')

# %%
female_df = df.loc[df['gender'] == 0]
male_df = df.loc[df['gender'] == 1]

yes_female_df = female_df.query('dec == 1')
no_female_df = female_df.query('dec == 0')
print('Proportion of acceptance by females is {}'.format(yes_female_df.shape[0]/female_df.shape[0]))

yes_male_df =male_df.query('dec == 1')
no_male_df = male_df.query('dec == 0')
print('Proportion of acceptance by males is {}'.format(yes_male_df.shape[0]/male_df.shape[0]))
# Out:
# Proportion of acceptance by females is 0.37481031866464337
# Proportion of acceptance by males is 0.488732806555458

# %%
def plot_feature(feature):
    fig = plt.figure(figsize=(8, 8))
    fig.subplots_adjust(hspace=0.5)
    
    ax = plt.subplot(211)
    ax.set_title('Female')
    ax.set_xlabel(feature)
    x = [no_female_df[feature].values]
    y = [yes_female_df[feature].values]
    plt.hist([x, y], label=['No','Yes'], bins=11)
    ax.legend()
    
    ax = plt.subplot(212)
    ax.set_title('Male')
    ax.set_xlabel(feature)
    x = [no_male_df[feature].values]
    y = [yes_male_df[feature].values]
    plt.hist([x, y], label=['No','Yes'], bins=11)
    ax.legend()
    plt.show()

# %%
#How do the distributions of certain features look like for 'yes' decision and 'no' decision

plot_feature('attr_partner')

# %%
plot_feature('intel_partner')

# %%
plot_feature('shar_partner')

# %% [markdown]
# Any more cool plots you can think of? Fiddle around with the dataset.
